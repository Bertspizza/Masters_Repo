# %% [markdown]
# # Plot CRQA outcomes across different parameters.

# %%
from utils_dir.graph_crqa_utils import *

delays = [4, 5, 10]
embedding = [3, 4, 5]
radii = [0.2, 0.25]

obs = ['whole_all_vel', 'head_all_vel', 'body_all_vel']
metric = 'DET'

# remove_couples = range(1, 39)
batch_plot_rqa_params(
    dir="...", # Path to directory containing the CRQA csv files.
    obs='headRel_ed_vel', # Metric (body_ed_vel)
    metric='REC', # CRQA index 
    delays=delays, 
    embeddings=embedding, 
    radii=radii, 
    minline=2, 
    print_obs=False, 
    count_err=False,
    collapse_windows=True, 
    remove_couples=None
)
